# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a51016/AIAC_16/blob/main/4_3_t4_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def count_vowels(input_string):
  """Counts the number of vowels in a string.

  Args:
    input_string: The string to count vowels from.

  Returns:
    The number of vowels in the string.
  """
  vowels = "aeiouAEIOU"
  count = 0
  for char in input_string:
    if char in vowels:
      count += 1
  return count

# Example usage:
string1 = "Education"
string2 = "Hello"

print(f"{string1} has {count_vowels(string1)} vowels.")
print(f"{string2} has {count_vowels(string2)} vowels.")
# Out:
# Education has 5 vowels.
# Hello has 2 vowels.
